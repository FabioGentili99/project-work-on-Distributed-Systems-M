# %%
import pandas as pd

AWS_js_hello = "AWS-js-hello.csv"
AWS_java_hello = "AWS-java-hello.csv"
AWS_go_hello = "AWS-go-hello.csv"

AWS_js_dynamo = "AWS-js-dynamo.csv"
AWS_java_dynamo = "AWS-java-dynamo.csv"
AWS_go_dynamo = "AWS-go-dynamo.csv"


df = pd.read_csv(AWS_go_dynamo)
df.sort_values(by='timestamp', ascending=True)
# Out:
#          timestamp                                            message  \
# 0    1725806276398  2024/09/08 14:37:56 Read from DynamoDB table e...
# 1    1725806276460  2024/09/08 14:37:56 Read from DynamoDB table e...
# 2    1725806277279  2024/09/08 14:37:57 Read from DynamoDB table e...
# 3    1725806277308  2024/09/08 14:37:57 Read from DynamoDB table e...
# 4    1725806277695  2024/09/08 14:37:57 Read from DynamoDB table e...
# ..             ...                                                ...
# 957  1725806557195  2024/09/08 14:42:37 Read from DynamoDB table e...
# 958  1725806557525  2024/09/08 14:42:37 Read from DynamoDB table e...
# 959  1725806557531  2024/09/08 14:42:37 Read from DynamoDB table e...
# 960  1725806557850  2024/09/08 14:42:37 Read from DynamoDB table e...
# 961  1725806564859  2024/09/08 14:42:44 Read from DynamoDB table e...
#
#                                          logStreamName
# 0    2024/09/08/[$LATEST]7abf60c22a9247cd8181ad0e3e...
# ...

# %%
list1 = []
list1 = df["message"].tolist()

list2 = []
for x in list1:
    list2.append(x.split(" "))

list3 = []
for x in list2:
    list3.append(int(x[-2]))

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array(list3)

fig, ax = plt.subplots(figsize = (20,8)) 
ax.set_title("Duration of service retrieval from DynamoDB")
ax.set_xlabel('Invocations')
ax.set_ylabel('Duration [ms]')
ax.plot(y)
ax.grid(True, linewidth=0.5)
ax.set_yticks(range(0,1550,50))
plt.show()
