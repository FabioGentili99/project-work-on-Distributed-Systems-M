# %%
import pandas as pd

AWS_js_hello = "AWS-js-hello.csv"
AWS_java_hello = "AWS-java-hello.csv"
AWS_go_hello = "AWS-go-hello.csv"

AWS_js_dynamo = "AWS-js-dynamo.csv"
AWS_java_dynamo = "AWS-java-dynamo.csv"
AWS_go_dynamo = "AWS-go-dynamo.csv"


df = pd.read_csv(AWS_js_hello)
df1 = pd.read_csv(AWS_java_hello)
df2 = pd.read_csv(AWS_go_hello)
df.sort_values(by='timestamp', ascending=True)
df1.sort_values(by='timestamp', ascending=True)
df2.sort_values(by='timestamp', ascending=True)
# Out:
#          timestamp                                            message  \
# 0    1725806276870  2024/09/08 14:37:56 hello world function execu...
# 1    1725806276903  2024/09/08 14:37:56 hello world function execu...
# 2    1725806277331  2024/09/08 14:37:57 hello world function execu...
# 3    1725806277371  2024/09/08 14:37:57 hello world function execu...
# 4    1725806277719  2024/09/08 14:37:57 hello world function execu...
# ..             ...                                                ...
# 957  1725806557229  2024/09/08 14:42:37 hello world function execu...
# 958  1725806557545  2024/09/08 14:42:37 hello world function execu...
# 959  1725806557549  2024/09/08 14:42:37 hello world function execu...
# 960  1725806557867  2024/09/08 14:42:37 hello world function execu...
# 961  1725806564878  2024/09/08 14:42:44 hello world function execu...
#
#                                          logStreamName
# 0    2024/09/08/[$LATEST]cbca40341ba44f828247b06b11...
# ...

# %%
list1 = []
list1 = df["message"].tolist()
list2 = []
for x in list1:
    list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-3]))
y = np.array(list3)


list1 = []
list1 = df1["message"].tolist()
list2 = []
for x in list1:
    list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-2]))
y1 = np.array(list3)


list1 = []
list1 = df2["message"].tolist()
list2 = []
for x in list1:
    list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-2]))
y2 = np.array(list3)

# %%
import matplotlib.pyplot as plt
import numpy as np



fig, ax = plt.subplots(figsize = (20,8)) 
ax.set_title("Duration of service retrieval from DynamoDB", fontsize = 40)
ax.set_xlabel('Invocations', fontsize = 34)
ax.set_ylabel('Duration [ms]', fontsize = 34)
ax.plot(y, label = 'js function')
ax.plot(y1, label = 'java function')
ax.plot(y2, label = 'go function')
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
ax.grid(True, linewidth=0.5)
#ax.set_yticks(range(0,2300,100))
plt.yscale('log')
plt.legend(loc = 'upper right')
plt.rc('legend', fontsize = 25)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


list1 = []
list1 = df["message"].tolist()
list2 = []
for x in list1:
    list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-3]))
y = np.array(list3)


list1 = []
list1 = df1["message"].tolist()
list2 = []
for x in list1:
    list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-2]))
y1 = np.array(list3)


list1 = []
list1 = df2["message"].tolist()
list2 = []
for x in list1:
    list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-2]))
y2 = np.array(list3)

# %%
fig, ax = plt.subplots(figsize = (20,8)) 
ax.set_title("Duration of invocation and execution of the hello-world Go function", fontsize = 40)
ax.set_xlabel('Invocations', fontsize = 34)
ax.set_ylabel('Duration [ms]', fontsize = 34)
ax.plot(y, label = 'js function', alpha = 1)
ax.plot(y1, label = 'java function', alpha = 0.8)
ax.plot(y2, label = 'go function', alpha = 0.8)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
ax.grid(True, linewidth=0.5)
plt.yscale ('log')
#ax.set_yticks(range(0,1300,50))
plt.legend(loc = 'upper right')
plt.rc('legend', fontsize = 25)
plt.show()
